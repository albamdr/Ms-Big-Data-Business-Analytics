# %% [markdown]
# ## EJERCICIO 2
#
# #### SE PIDE:
#
# Dado un archivo que contiene en cada línea una palabra o conjunto de palabras seguido de un valor numérico denominado “sentimiento” y un conjunto de tweets, se pide calcular el sentimiento de aquellas palabras o conjunto de palabras que no tienen un valor asociado en el archivo de “sentimientos”. Se pueden seguir distintas estrategias para asignar un valor. Por ejemplo, se podría asignar como valor el valor del “sentimiento” del tweet en que se encuentra la palabra o conjunto de palabras sin valor, o el valor medio del “sentimiento” del tweet.
#
# Como resultado se debe mostrar por pantalla en cada línea, una palabra o conjunto de palabras y a continuación un valor numérico que represente el “sentimiento” de dicha palabra o conjunto de palabras. Solo se mostrarán la palabra o conjunto de palabras que no aparecían con un valor en el archivo original.
#
# No todos los tweets que se van a considerar tienen contenido, por lo que hay que filtrar aquellos que tienen de los que no tienen.
#
# El programa tendrá 2 parámetros de entrada: el archivo que contiene los sentimientos de los términos y el archivo que contiene los tweets.

# %% [markdown]
# #### Ejemplo
#
# Si se toma como referencia el tweet anterior:
#
# - I will go on vacation to the beach.
#
# Sabemos que las palabras 'vacation' y 'beach' ya tienen un valor asociado en el archivo de sentimientos; por lo tanto, tenemos que actualizar el sentimiento del resto de palabras. Podríamos hacerlo de dos formas:
#
# **Versión 1, asignando el valor del sentimiento del tweet (3) a las palabras:**
#
# - 'I': 3
# - 'will': 3
# - 'go': 3
# - 'on': 3
# - 'vacation': No mostramos esta palabra, dado que tiene un sentimiento ya asociado anteriormente.
# - 'to': 3
# - 'the': 3
# - 'beach': No mostramos esta palabra, dado que tiene un sentimiento ya asociado anteriormente.
#
# **Versión 2, asignando la media del valor del tweet, siendo esta media el número de palabras del tweet dividido entre el valor de sentimiento del tweet; el tweet de ejemplo tiene 8 palabras, por lo tanto, 8 ÷ 3 = 2.66.**
#
# - 'I': 2.66
# - 'will': 2.66
# - 'go': 2.66
# - 'on': 2.66
# - 'vacation': No mostramos esta palabra, dado que tiene un sentimiento ya asociado anteriormente.
# - 'to': 2.66
# - 'the': 2.66
# - 'beach': No mostramos esta palabra, dado que tiene un sentimiento ya asociado anteriormente.

# %% [markdown]
# ## SOLUCIÓN

# %%
#importamos los módulos que vamos a necesitar
import json

# %%
#definición función que pasa el fichero de sentimientos a diccionario

def fichero_sentimientos_to_dict(fichero_sentimientos):
    
    sentimientos = open(fichero_sentimientos) 
    dict_sentimientos = {} 
    
    for linea in sentimientos: 
        termino, valor = linea.split("\t") 
        dict_sentimientos[termino] = int(valor) 
        
    return dict_sentimientos

# %%
#definición función que pasa el fichero de tweets a lista de tweets

def fichero_tweets_to_list(fichero_tweets):
    
    tweets = open(fichero_tweets)
    
    lista_tweets = []
    
    for linea in tweets:
        
        #seleccionamos solo el contenido de 'text' que es donde se encuentra el tweet
        if 'text' in json.loads(linea):
            lista_tweets.append(json.loads(linea)['text'])
        else:
            pass
        
    return lista_tweets

# %%
#definición de la función que calcula el sentimiento asociado a un tweet

def sentimientos(diccionario_sentimientos, tweet):
    
        valor_sentimientos = 0
        
        for palabra in tweet.split():
            
            if palabra.lower() in diccionario_sentimientos:
                valor_sentimientos += diccionario_sentimientos[palabra.lower()]
            else:
                pass
        
        return valor_sentimientos

# %%
#definición de la función que calcula el sentimiento asociado a las palabras que no aparecen en el diccionario de sentimientos
#utilizando las dos versiones de solución

def valor_sentimientos(diccionario_sentimientos, tweet):
        
        #calculamos el valor de sentimiento utilizando la versión 1 de solución
        valor_1_sentimientos = sentimientos(diccionario_sentimientos, tweet)
        
        #calculamos el valor de sentimiento utilizando la versión 2 de solución
        if valor_1_sentimientos != 0:
            valor_2_sentimientos = len(tweet)/sentimientos(diccionario_sentimientos, tweet)
        else:
            valor_2_sentimientos = valor_1_sentimientos
            
        palabras_sin_valor = []
        
        #seleccionamos las palabras del tweet que no tienen valor asociado
        for palabra in tweet.split():
            
            if palabra.lower() not in diccionario_sentimientos:
                palabras_sin_valor.append(palabra.lower())
            else:
                pass
        
        return palabras_sin_valor, valor_1_sentimientos, valor_2_sentimientos

# %%
#programa principal

if __name__ == "__main__":
    
    #leemos los nombres de los ficheros por entrada de teclado
    sentimientos_file = input('Fichero de sentimientos: ')
    tweets_file = input('Fichero de tweets: ')
    
    #convertimos el fichero sentimientos en dict y el fichero tweets en list
    sentimientos_dict = fichero_sentimientos_to_dict(sentimientos_file)
    tweets_list = fichero_tweets_to_list(tweets_file)
    
    #para cada tweet calculamos el valor de sentimiento (versión 1 y versión 2) asociado a las palabras sin valor y lo printeamos
    for tweet in tweets_list: 
        
        lista_palabras, valor_1_sentimientos, valor_2_sentimientos = valor_sentimientos(sentimientos_dict, tweet)
        
        if len(lista_palabras) > 0:
            
                print('-'*50)
                print('LAS SIGUIENTES PALABRAS:', lista_palabras, '\n')
                print('TIENEN UN SENTIMIENTO ASOCIADO DE:', valor_1_sentimientos, '(versión 1) Ó', valor_2_sentimientos, '(versión 2)')
# Out:
# Fichero de sentimientos: Sentimientos.txt
# Fichero de tweets: Tweets.txt
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@brenamae_', 'i', 'whale', 'slap', 'your', 'fin', 'and', 'tell', 'you', 'one', 'last', 'time:', 'go', 'awhale']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['metin', 'şentürk', 'twitterda', '@metinsenturk', 'muhteşem', 'üçlü;', 'sen,', 'ben,', 'müzi̇k']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@byunghns:', '😭', 'i', '#틴탑', 'so', 'much', '#쉽지않아', 'is', 'going', 'to', 'be', 'so', '😭']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 6 (versión 1) Ó 10.833333333333334 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['que', 'hdp', 'maicon', 'lo', 'que', 'le', 'hizo', 'a', 'david', 'luiz', 'jajajajajajajajajajaj,igual', 'se', 'jodio', 'la', 'carrera']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['ドライ！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@positivamos:', 'tudo', 'o', 'que', 'eu', 'quero', 'é', 'um', 'amor', 'sincero.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@gossiproomoff:', 'si', 'nathalie', 'sait', 'pertinemment', 'que', 'son', 'couple', 'ne', 'va', 'pas', 'durer,', 'alors', 'pourquoi', 'accepter', 'la', 'demande', 'en', 'mariage', 'de', 'vivian', '?', '…']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@dayannalozano_:', 'junior', 'va', 'perdiendo...', 'http://t.co/5mosr7bolx']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@positivamos:', 'tudo', 'o', 'que', 'eu', 'quero', 'é', 'um', 'amor', 'sincero.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@positivamos:', 'tudo', 'o', 'que', 'eu', 'quero', 'é', 'um', 'amor', 'sincero.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['الله', 'أكبر', 'الله', 'أكبر', 'الله', 'أكبر,', 'لا', 'إله', 'إلا', 'الله,', 'الله', 'أكبر', 'الله', 'اكبر', 'ولله', 'الحمد', 'http://t.co/m454ohqpyy']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ["twi̇tter'i", 'akrabalar', 'keşfedi̇cek', 'di̇ye', 'çok', 'korkuyorum', 'metin', 'şentürk', 'twitterda', '@metinsenturk']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@pinkbatharry:', 'les', 'saintes', 'nitouches', 'de', 'ma', 'classe', 'qui', 'aiment', 'les', '5sos', 'si', 'je', 'leur', 'montre', 'le', 'vine', 'de', 'la', 'bite', 'a', 'calum', 'on', 'verra', 'si', 'elles', 'son…']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@le_parisien:', 'ebola', ':', 'des', 'pilotes', "d'air", 'france', 'refusent', 'les', 'vols', 'vers', 'les', 'pays', 'touchés', 'http://t.co/lt37qkdwr2']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@hailee_danielsx', "i'm", 'not', 'mean', 'cuz', "i'm", 'so', 'ya']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: -3 (versión 1) Ó -16.0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['you', 'believe', 'your']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 5 (versión 1) Ó 6.6 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@baileymac02:', "can't", 'wait!', 'i', 'am', 'playing', '@soccersix', 'at', 'the', 'london', 'soccerdome', 'on', 'sunday', '26th', 'october!', 'tickets', 'selling', 'fast:', 'http://t.co/c6i…']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@positivamos:', 'tudo', 'o', 'que', 'eu', 'quero', 'é', 'um', 'amor', 'sincero.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['ドラコ・マルフォイ', '「闇の帝王が支配なさる時、owlやnewtが何科目なんて『あの人』が気になさるか？もちろん、そんなことは問題じゃない・・・『あの人』のためにどのように奉仕し、どのような献身ぶりを示して来たかだけが重要だ」']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@reading_bot_:', '마주앉는다는', '것은', '눈으로', '보기를', '좋아한다는', '것이다.', '옆에', '앉는다는', '것은', '손으로', '만지기를', '좋아한다는', '것이다.', '그러니까', '남자들은', '시각', '중심적이고', '여자들은', '촉각', '혹은', '후각', '중심적이다.', '(이문재,', '아주', '낯선', '낯익은', '이야기)']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@en7raaf69:', 'عبودي', 'من', 'الرياض', 'ينآك', 'آآح', 'يالدلع', 'http://t.co/hs1h0xwpao', '#افلام_سكس', '#ممحونه', '#ورعان', '#سكس', '#ديوث', '#سالب', '#قحبه', '#خلفي', '#فلم', '#محارم', '…']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['vince', 'staples', 'so', 'cold']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@chinamiiii721', '球児？', 'わからんか', 'もう一人の方は？あのギャル見たいな子']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@positivamos:', 'tudo', 'o', 'que', 'eu', 'quero', 'é', 'um', 'amor', 'sincero.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ["'"]
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['#abrahammateoencanalfiesta', '@dominguezja', 'necesito', 'que', 'me', 'susure', 'al', 'oido,', 'abrazarlo,', 'sentir', 'su', 'calor..', 'todo', 'lo', 'que', 'siempre', 'e', 'deseado!.p']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@appie_france', 'mais', 'ne', 'vs', 'sentez', 'pas', 'agressé,', 'même', 'non', 'officiel', 'votre', 'compte', 'est', 'intéressant', 'car', 'rassemble', 'les', 'différentes', 'infos.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@positivamos:', 'tudo', 'o', 'que', 'eu', 'quero', 'é', 'um', 'amor', 'sincero.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['http://t.co/chp71m0uce']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@nashgrier:', 'birthday', 'to', 'one', 'of', 'my', 'friends', '@jackgilinsky', "can't", 'wait', 'till', "you're", 'out', 'in', 'la!', 'have', 'a', 'one!']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 9 (versión 1) Ó 13.333333333333334 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['i', 'a', '@youtube', 'video', 'from', '@jordzcreations', 'http://t.co/yjhzcimxhg', '5', 'rated', 'players', 'in', 'fifa15!', '(messi,', 'ronaldo', '&amp;', 'ibra!)']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 4 (versión 1) Ó 32.0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@kirkjtorrance:', "cat's", 'out', 'of', 'the', 'bag!', '"@williamjhague:', 'giving', 'scotland', 'more', 'powers', 'if', 'it', 'votes', 'is', 'not', 'government', 'policy"', 'http://t.co/…']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: -1 (versión 1) Ó -140.0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@nasa:', 'roiling', 'flows', 'of', 'lava', 'on', 'holuhraun', 'lava', 'field', 'seen', 'by', '@nasa_landsat', 'in', 'iceland:', 'http://t.co/3ogfkivcfv', '#earthrightnow', 'http://t.co…']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['続編きたあああ', '#prismaillya']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['"@jaureguisteam:', 'vou', 'ter', 'que', 'começar', 'com', 'as', 'ameaças', '#mtvema', '#nominatefifthharmony"']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['http://t.co/emqdw8bhkx']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@pbirdly:', 'just', 'setting', 'up', 'my', 'twitter.', '#myfirsttweet']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@positivamos:', 'tudo', 'o', 'que', 'eu', 'quero', 'é', 'um', 'amor', 'sincero.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@dr_alqarnee:', 'لست', 'مسئولاً', 'عن', 'ذنوب', 'الناس,', 'فقط', 'ابكِ', 'على', 'نفسك,', 'ونُح', 'على', 'روحك', '(كُلُّ', 'نَفسٍ', 'بِمَا', 'كَسَبَت', 'رَهِينَةٌ).']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['kıskancım', 'canım', 'ben,', 'başlatma', 'kankana,', 'kardeşine', 'metin', 'şentürk', 'twitterda', '@metinsenturk']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@positivamos:', 'tudo', 'o', 'que', 'eu', 'quero', 'é', 'um', 'amor', 'sincero.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@disneywords:', 'are', 'as', 'real', 'as', 'you', 'them', 'to', 'be.', 'are', 'as', 'real', 'as', 'the', 'sky', 'and', 'the', 'sea.', '–peter', 'pan', '(disney', 'dreams)']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 3 (versión 1) Ó 43.0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@ste1nkopf:', 'http://t.co/ptmae4l2mt', 'печать', 'бланков']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@a7laahm85:', "أميرت'ن", 'م', 'همّها', 'لبس', 'وعقوود', "صعب'ن", 'على', 'من', 'حبّها', 'مشتراها', 'تذبح', 'ب', 'كثر', 'الملح', 'وعيونها', 'السود', 'وتقصر', 'جميع', 'الغيد', 'عنّ', 'مستواها', '🌹🌹أمجاد']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@positivamos:', 'tudo', 'o', 'que', 'eu', 'quero', 'é', 'um', 'amor', 'sincero.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@aurinth', 'i', 'think', "it's", 'possible,', 'and', 'sometimes', 'scenes', 'that', 'can', 'work', 'as', 'long', 'as', "they're", 'bookended', 'by', 'some', 'sort', 'of', 'development.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 2 (versión 1) Ó 64.5 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['http://t.co/mfdtyt81ux']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@positivamos:', 'tudo', 'o', 'que', 'eu', 'quero', 'é', 'um', 'amor', 'sincero.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@positivamos:', 'tudo', 'o', 'que', 'eu', 'quero', 'é', 'um', 'amor', 'sincero.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@elofwind', '중소기업이라', '잡무만', '따로', '뽑지는', '않지만', '면접때', '막내는', '이런것도', '해야한다', '분명히', '말을', '하고', '뽑아도', '그런말', '들어본', '적', '없다는듯이', '행동하는', '애들이', '점점', '많아집니다..', '-.-', '@misty8628']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['みーせてーみせてどーぉかーみせてうんとがんばっちゃーう']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['もうお昼の時間だね。話題は変わるよ。今日は色々朝から調べ物をしてたよ。ps２の薄型本体のやつが故障のせいか、どのディスクを入れても、[読み込み失敗しました]てでるから、sceのサポートセンターに電話(面接の電話は？)して、修理に出す準備してたよ。早く治って欲しいや']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@jackalltimelow:', 'i', 'am', 'in', 'my', 'cab', 'and', '@5sos', 'came', 'on', 'radio.', 'i', 'came', 'too']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: -2 (versión 1) Ó -38.0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@soldierrofallah:', 'shaytaan', 'makes', 'sin', 'attractive', 'to', 'us']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@singlejocoffee', 'i', 'to', 'think', 'i', 'do', 'everything', 'a', 'rebellious', 'poet.....']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 4 (versión 1) Ó 18.75 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@positivamos:', 'tudo', 'o', 'que', 'eu', 'quero', 'é', 'um', 'amor', 'sincero.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@pointlessblog:', "who's", 'ready', 'for', 'a', 'horror', 'gaming', 'video!?']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@positivamos:', 'tudo', 'o', 'que', 'eu', 'quero', 'é', 'um', 'amor', 'sincero.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['chancho', '🐷🐷🐷', 'http://t.co/lmytpeilgf']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@sovainikita:', '@pallomaagon', 'me', 'manda', 'o', 'teu', 'whats']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['قال', 'صلى', 'الله', 'عليه', 'وسلم', 'يا', 'أيها', 'الناس', 'إن', 'منكم', 'منفرين', 'فأيكم', 'ما', 'صلى', 'بالناس', 'فليوجز', 'فإن', 'فيهم', 'الكبير', 'والضعيف', 'وذا', 'الحاجة', '--', 'صحيح', 'البخاري', '#hadith']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['伊紙、先制アシストの長友をmomに選出「一連の動きはパーフェクト」', 'http://t.co/ut33gnioy3', '長友はフル出場し、75分にマウロ・イカルディの先制点を右からのクロスでアシストした。', 'http://t.co/bupyqlnfr6']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['muulher', 'scrr', '%%%%', 'pqpsgjff', 'http://t.co/v8fkloo0p5']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['“@djzeeti:', 'twitpic', 'a', 'selfie', 'that', 'will', 'get', 'alot', 'of', 'retweets”', 'http://t.co/zlk66haeoo']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@positivamos:', 'tudo', 'o', 'que', 'eu', 'quero', 'é', 'um', 'amor', 'sincero.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['xxx', 'vids:', 'chick', 'cameron', 'hardcore', 'teen', 'sex', '#porn', '#followback', '#teen', '#itunes', 'http://t.co/sz4pcq4l6n']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 6 (versión 1) Ó 18.0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['metin', 'şentürk', 'twitterda', '@metinsenturk', 'öylede', 'güzel', 'böylede', 'güzel']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['need', 'to', 'get', 'this', 'trim..', 'can’t', 'be', 'boarding', 'plane', 'to', 'more', 'looking']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 1 (versión 1) Ó 83.0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['amaia', 'necesito', 'un', 'certificado', 'para', 'mañana', 'presentar', 'al', 'cole', 'saludame', 'xdd', ':)', '(@amaiamontero', 'live', 'on', 'http://t.co/0ohhbjbvkf)']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['http://t.co/qlqzmzz49f']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['yo', 'dough!', 'why', 'she', 'hit', 'you?']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['is', 'this', 'not', 'the', 'idea', "we've", 'thought', 'of', 'yet?', '#dominos', '#sandwich', 'http://t.co/kyibyzw9av']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 3 (versión 1) Ó 29.666666666666668 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@briflubia:', 'http://t.co/3ohxwcq12l...', 'http://t.co/tv1hgfjxem']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['metin', 'şentürk', 'twitterda', '@metinsenturk', 'daha', 'iyi', 'olmaya', 'çalışmayan', 'iyi', 'olarak', 'ta', 'kalamaz.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['ちょいまって日曜って今週の？']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['if', 'only', 'i', 'could', 'put', 'my', 'thoughts', 'into', 'words']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@elvinelol:', 'world', 'of', '#warcraft', 'raiding', 'lengths', 'by', 'expansion', '#wow', '#pve', 'http://t.co/ikoke02heo']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@m199z:', '@azooz201144', '@mhmd350', '@aser541', '@zainsaudi', '@225_mg', '@sak5511', '@ms3ry_502', '@aser2211', '@aser5411', '@abusaud20001', '@v__i___p', '@al3bdli_q8']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@jchristofides:', 'p2p', 'видео', 'http://t.co/vh5ebroa3h']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@1k305:', '💞\u06dd💞\u06dd💞💎➊', '#فرصتك✔💎➋', '#لزيادة_متابعينك✔💎➌', '#ريتويت✔♻💎➍', '#فولومي✔💎➎', '#فولوباك✔💎➏', '#اضافة_من_عمل_ريتويت.', '💞\u06dd💞\u06dd💞']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['assunto', 'nas', 'aulas:', '1+1=2', 'assunto', 'nas', 'provas:', 'qual', 'o', 'valor', 'de', 'x,', 'se', 'y', 'é', 'igual', 'a', 'distância', 'do', 'sol', 'com', 'a', 'terra?', '😒😱📖🙌']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['due', '#mtvema', '#nominatearianagrande']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@s_r_n__', 'せやん']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@faizamirza84:', 'dr', '#tuq:', '8', 'arab', 'rs', 'is', 'used', 'daily', 'on', 'corruption', 'in', 'pakistan', '#statusquovsoppressed']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['シラヌイだって38とかだからさぁ・・・']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@cthagod:', 'i', 'keep', 'making', 'the', 'of', 'talking', 'to', 'people', 'who', "don't", 'know', 'what', 'they', 'are', 'talking', 'about.......']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: -2 (versión 1) Ó -54.5 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['อยากกินบอนชอน', 'อยากกินไก่ทอด', 'อยากกินซุปกิมจิ', 'อยากกินเกี๊ยวซ่า', 'อยากกินทุกอย่างอ่ะตอนนี้', 'หิววววว...!!!', '😭😂']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['-', 'queimar', 'a', 'lingua', 'café', '&amp;', 'uma', 'das', 'piores', 'coisas', ':(', ":'(", ':(']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: -1 (versión 1) Ó -64.0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@raissawktkalex', 'waooo', 'i', 'see', ';;;;']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['скачала', 'наконец', 'то', 'сайлент', 'хилл', 'супер', 'город,у', 'меня', 'просто', 'нет', 'слов))']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['わけわからんｗｗｗｗｗ', '(', '@ayaka15fu', '小声cas。雑談', 'http://t.co/4ny0qdtfuk', ')']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['293']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@kiavess', '@chilledewd', 'xd', 'shush']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@zharntika_:', 'naif', 'sekali,', 'justru', '@sbyudhoyono', 'g', 'becus', 'ngurus', 'hkm', 'krn', 'bmasalah', 'dg', 'hkm', '@tm2000back', '10.', 'harusn...', 'http://t.co/3aljeckx40']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@yuxki', '@zibakurei_bot', 'っしょァァ！']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@chi_tanmama', '浜松なうだよwww', '雷えぐい！！', 'ありがとー^', '^']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['van', 'morrison', '-', 'gloria', '&lt;3']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['com.android.internal.os.zygoteinit$methodandargscaller.run(zygoteinit.java:1259)', 'at', '(29/57)']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['ขอเพิ่มเติมเกี่ยวกับความแตกต่าง', 'และความสัมพันธ์เกี่ยวกับ', 'container', 'กับ', 'codec', 'นะครับ', 'ระบบนี้เกิดขึ้นในยุค', 'digital...', 'http://t.co/mpzwzuz8eg']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@euhanjung:', '"@salvado10903734:', 'http://t.co/bizbcq0qjr"~', 'greed~']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: -2 (versión 1) Ó -36.5 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['clothing', '&amp;', 'shoes', '&gt;&gt;', 'champion', 'textured', 'dazzle', "men's", 'basketball', 'shorts', '-', 'style', '82619', '#048', 'http://t.co/5gsfqgmxvn', 'http://t.co/n99xgindgj']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@laerciosoficial:', '▬▬▬▬ஜ۩۞۩ஜ▬▬▬▬', '★#connect', 'the', '#world★', '☑️integration', '☑️team', '☀#teamfree', '#free', '▬▬▬▬ஜ۩۞۩ஜ▬▬▬▬', '#tfbjp', '@retweetsjp']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@lfcfaisal:', 'الى', 'الحين', 'منب', 'فاهم', 'ليش', 'ليفربول', 'مو', 'مثل', 'باقي', 'الاندية', '؟', 'يصاب', 'اللاعب', 'ويرجع', 'ويصاب', 'مره', 'ثانيه', 'ولا', 'نعرف', 'كم', 'مدة', 'غيابه']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@aartic02:', 'victory', 'of', 'aap', 'will', 'be', 'victory', 'of', 'common', 'people', '#onlyaap4delhi']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['es', 'imposible', 'aguntar', 'en', 'mi', 'casa.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['"@utahjazz:', 'jeremy', 'ekans', '#nbapokemon', 'http://t.co/nzvbiq3zk1"', '😅😅😅😅']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['why', 'you', 'time', 'on', 'someone', 'when', 'they', "don't", 'give', 'you', 'any', 'of', 'their', 'time']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: -1 (versión 1) Ó -72.0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['mgkin', 'apa', 'yg', 'kau', 'nak', 'x', 'diberi', 'krn', 'ada', 'yg', 'lbh', 'baik', 'sdg', 'menanti.', 'berdoalah.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@pbirdly:', 'just', 'setting', 'up', 'my', 'twitter.', '#myfirsttweet']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['أخت', 'المعرس', 'أول', 'مايدخل', 'اخوها', 'الصالة:', 'http://t.co/x5ftgbimhd']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@t1dfu:', '@sunshinexziall', 'on', 'a', 'pas', 'encore', 'définis', 'tous', 'les', 'lieux', 'et', 'dates,', 'suis', 'nos', 'tweets', 'on', 'les', 'tweetera', 'bientôt']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['『mステ', 'スーパーライブ2013', '嵐、akb48、ゴールデンボンバー、ももクロ、関ジャニ∞、kis', 'my', 'ft2、exile、man', 'with', 'a', 'mission、前田敦子ら』', 'http://t.co/rez5kxfanc', '-youtube', '-動画まとめ']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@connpost:', '#milford', 'school', 'janitor', 'for', 'leaving', 'gifts,', 'notes', 'for', 'student', 'http://t.co/rjv7hybufg']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: -3 (versión 1) Ó -35.333333333333336 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['me', 'mueeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeero', 'por', 'ir', 'a', 'desfilar', '-.-']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['グラードンとカイオーガの新特性つよそう']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@thebestoftumbir:', 'http://t.co/qzuxmuxgrg']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@alkhaldi_ksa:', '#قطر_راعية_الارهاب', 'اهلنا', 'بالبحرين', 'فتحوا', 'العين', 'عدل', 'هالايام', 'وخاصة', 'من', 'جهة', 'البحر', 'جنوب', 'وجنوب', 'شرقي']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['я', 'ничего', 'не', 'боюсь,', 'потому', 'что', 'у', 'меня', 'есть', 'хронометр', 'времени!', 'с', 'бонусами', 'играть', 'намного', 'проще!', 'http://t.co/uob2xxnmni', '#ipad', '#...']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['"@pointlessblog:', "who's", 'ready', 'for', 'a', 'horror', 'gaming', 'video!?"', 'my', 'body', 'is', 'ready']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['ur', 'bud']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: -2 (versión 1) Ó -5.5 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['دعاء', 'الغضب:أعوذ', 'بالله', 'من', 'الشيطان', 'الرجيم', 'http://t.co/igsq7clz0q']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['dag', '2', 'http://t.co/uukpd2tn6d']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@la12tuittera', '@americancloss', 'alguien', 'podría', 'explicar', 'el', 'por', 'qué?', '?']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['now', 'playing:', 'gaby', 'baginsky', '-', 'heute', 'morgen', 'immer', 'und', 'ewig', '#on', 'schlagergarage']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['blunote.it', '|', 'svolta', 'grottaglie,', 'pizzonia', 'nuovo', 'tecnico', 'http://t.co/ki7i6zouaw']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@nouriaaajxo:', '👌', 'http://t.co/5ugceubu6b']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['metin', 'şentürk', 'twitterda', '@metinsenturk', 'sen', 'o', 'kızı', 'üzüyorsun', 'ama', 'o', 'seni', 'seviyor.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@tweetpotweet', '@rts_sport', 'bruka!!!']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['عمره', '١١', 'سنة', 'ويكتب', ':', 'ترى', 'الجفاء', 'بعد', 'الوفاء', 'عندنا', 'عيب', '.', 'اي', 'جفاء', 'واي', 'وفاء', '؟', 'اربع', 'اغاني', 'لام', 'كلثوم', 'اطول', 'من', 'حياتك', '"̮*beer*', '.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@mmez11:', 'للمتواجدين', '⭕لمتابعة', 'أكثر', 'من[900', 'الف]مغرد', '➊', 'فولو', 'مي', '@mmez11', '➋', 'ريتويت', '➌', 'فولو', 'للي', 'عمل', 'رتويت', '➍', 'فولو', 'باك', '➎', 'اللي', 'ما', 'يلتزم', 'ما', 'بيستفيد', '…']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['やったー続編！']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@4qh3_', '1o3q8ieshi']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@mariam_63', 'entra', 'aca', 'y', 'le', 'ragalas', 'unos', '15', 'minutos', 'de', 'votos', 'a', 'lucero', 'xfa.', 'gracias', '!!!', 'http://t.co/cltkgmdxe8', '#ysea']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['sneezing']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: -2 (versión 1) Ó -9.0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@belu_cervantes', 'jajaja..', 'felicidaaaaadeees', 'tontula', 'me', 'acabo', 'de', 'enterar', 'que', 'aprobaste']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['ஙே', 'என்னாச்சி', 'பழசு', 'வது', 'ஙே']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['en', 'el', 'bus', 'demos', 'prioridad', 'a', 'niños,mujeres', 'embarazadas,', 'personas', 'de', 'la', 'tercera', 'edad', 'y', 'con', 'discapacidad.', 'hagamos', 'de', 'montería', 'una', '#ciudadamable']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['i', 'just', 'took', 'a', 'test', 'where', 'the', 'answer', 'to', 'a', 'question', "mozart's", 'dad.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@maxiipoli:', 'iara', 'es', 'la', 'mejor', 'y', 'me', 're', 'ama']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@louis_tomlinson:', 'the', 'for', 'the', 'new', 'album', 'and', 'fireproof', 'has', 'been', '!', 'so', 'so', 'for', 'you', 'all', 'to', 'hear', 'more', '!', 'loveeeee']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 9 (versión 1) Ó 14.777777777777779 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['trato', 'de', 'ser', 'mejor', 'que', 'nadie,', 'trato', 'de', 'ser', 'lo', 'mejor', 'que', 'te', 'sucedido', 'en', 'la', 'vida.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 1 (versión 1) Ó 85.0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['metin', 'şentürk', 'twitterda', '@metinsenturk', 'pijamasını', 'yere', 'doğru', 'çıkarıp,', 'ayağı', 'ile', 'yukarıya', 'fırlatıp', 'tutanlar', 'derneği...']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@esppeonzaguirre:', 'ojo', 'con', 'las', 'bananas...¡arañas!', '¡yo', 'prefiero', 'los', 'plátanos', 'canarios!', 'además...', 'mejor', 'sabor', 'http://t.co/uccsqgrq6e', 'http:/…']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@almusaffer:', 'بعض', 'الأشخاص', 'عند', 'حضوره', 'يشعر', 'الجمع', 'بأنه', 'اضفى', 'على', 'المكان', 'رحابة', 'وعلى', 'الحضور', 'راحة', 'لسلوكه', 'الرفيع', 'وابتعاده', 'عن', 'الفظاظة', 'والوقاحة', 'وال…']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@zodiacohoy:', '#sagitario', 'hoy', 'recuerda', 'que', 'es', 'bueno', 'soñar', 'pero', 'es', 'mucho', 'mejor', 'hacer,', 'deja', 'por', 'un', 'momento', 'los', 'sueños', 'y', 'empieza', 'a', 'hacerlos', 'r…']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@dodi_gigolo:', 'pin:2b1d7c60', 'dodi', 'escort', 'bot', 'manly,', 'yg', 'mau', 'di', 'isep', 'servis', 'memuas', 'kan', 'stay', 'di', 'jak', 'pus', 'tlp', '081317117763', 'http://t.co/inqo3sks…']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['うおおおおおおおお！！']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['omg', '😍😍😍']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 2 (versión 1) Ó 6.0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@thiagoarruee', 'vannn??']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['говорят,', 'сегодня', 'день', 'рождения', 'нашего', 'общего', 'друга', '-', 'мэтью', 'ли', '(мэтт', 'ли)!!', 'доброго', 'здоровья,', 'дорогой', 'друг', 'и...', 'http://t.co/z0psetulyy']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@onedirection:', 'if', 'you', 'pre-order', '#1dalbumfour', 'from', 'the', '1d', 'store,', "you'll", 'get', 'a', 'wrist', 'band', 'on', 'the', 'day', 'of', 'release', 'http://t.co/tdx9ujdlgu', 'htt…']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@semihkiziltan:', 'fed,', 'ziraatbank', 'soruşturmasını', 'başlattı', 've', 'milyarca', 'dolarlık', 'ceza', 'verebilir.', 'bakarsınız', 'seneye', 'ziraati', 'basya', 'satın', 'alır', '…']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@mugsy4fly', 'lol!', 'but', "she's", 'a', 'famous', 'twitter', 'personality!!!', '(it', 'over', 'sarah', 'palin,who', 'i', 'really', '-', 'but', "don't", 'think', 'should', 'run', 'for', 'potus)']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 2 (versión 1) Ó 70.0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@sarahcourcis', 'ouai', 'mais', 'je', 'vais', 'courir', 'la', '!', '😜💪']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@apuri_kamisama:', '課金を無料に、', 'これ今はみんなやってますよww', 'やらないと、損しかありませんw', '→http://t.co/dewahckgoc', '馬鹿らしい課金は、卒業してくださいw', 'http://t.co/w4uzsfkper']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@_helloitsjo', 'lmaoo', 'ok', 'i', 'remeber', 'you']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@dalidragibus1:', 'câlin', 'http://t.co/uzmnaichmp']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@m_alhtershi:', 'أتمنى', 'من', 'جماهير', 'عميد', 'الأندية،،', 'اغلاق', 'موضوع', 'المدرب', 'الجديد(مؤقتاً)،،', 'لمابعد', 'مبارتنا', 'مع', 'العروبة،،', 'نقاط', 'العروبة', 'مهمة', 'جداً', '…']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@1967denberi:', 'alanzinho', '-', 'jaja', '-', 'yattara', '#trabzonspor', 'http://t.co/9hil7g7nbw']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@themotherhood', 'thx', 'for', 'having', 'us!', '#unstoppablemoms']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@1435p:', '⭕', 'المتواجديــن', '⭕', 'لزيادة', 'متابعينكم', '➊', 'فولومي', '➋', 'ريتويت', '➌', 'فولو', 'اللي', 'عمل', 'ريتويت', '➍', 'فولو', 'باك', '➎', 'اتبعوا', 'الخطوات', 'السابقة', 'لزيادة', 'متابعينكم', '…']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@belen_chaya', 'jajaja', 'dije', 'lo', 'missmo']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['せっかくワンピース持ってきたから着ようかな。アクセサリーも。']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@world_images_:', 'can', 'you', 'give', 'me', 'a', 'little', 'push?', 'http://t.co/fpioaady2s']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@arab_panorama:', 'بالسينما', 'يقبض', 'الممثل', 'ملايين', 'كذلك', 'المخرج', 'والممتج', 'المستفيد', 'الاكبر,', 'أما', 'بفليم', 'داعش', 'المخرج', 'السيناريست', 'والمنتج', 'خسروا', 'لان', 'الم…']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@soccerseki824', 'まあ、そこら辺はまた（笑）']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['ニルヴァーシュが２時をお伝え！']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@anooood1401', 'سلام']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['just', 'ahhhhhh😍😍😍😍🙌😱😍😍😍', 'http://t.co/eadv1r3u4j']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@yuuna623815', 'え、なにしたん']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@chlldhoodruiner:', 'jay', 'z', '44', 'and', 'beyoncé', '32', 'so', "i'm", 'not', 'gonna', 'stress', 'it', 'cause', 'bae', 'starts', '1st', 'grade', 'tomorrow']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@laerciosoficial:', '▬▬▬▬ஜ۩۞۩ஜ▬▬▬▬', '★#connect', 'the', '#world★', '☑️integration', '☑️team', '☀#teamfree', '#free', '▬▬▬▬ஜ۩۞۩ஜ▬▬▬▬', '#tfbjp', '@retweetsjp']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@qo_500:', '-', 'وَقَدْ', 'يَنْكَسِرُ', 'بِالنَّفْسِ', 'شَيء', 'لا', 'يَجْبرُهُ', 'ألْفُ', 'اعْتِذَار..']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@ru_ru50', 'beat', 'that', '19', 'times', 'tonight', '😉😏😘']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: -6 (versión 1) Ó -7.833333333333333 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@sandratorensma:', 'http://t.co/np9z6ln95y']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@maamsalcatraz:', 'cette', 'gomme', 'la', 'plus', 'grosse', 'arnaque', 'du', 'siècle', 'elle', 'était', 'sensé', 'gommé', 'ls', 'stylo', ',mais', 'elle', 'déchirer', 'la', 'feuille', 'cet', 'pute', 'htt…']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@missshosh4:', 'اروع', 'ما', 'في', 'السجود', 'انك', 'تهمس', 'في', 'اذن', 'الأرض', 'فيسمعك', 'من', 'في', 'السماء♡']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@laerciosoficial:', '▬▬▬▬ஜ۩۞۩ஜ▬▬▬▬', '★#connect', 'the', '#world★', '☑️integration', '☑️team', '☀#teamfree', '#free', '▬▬▬▬ஜ۩۞۩ஜ▬▬▬▬', '#tfbjp', '@retweetsjp']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@jmfmoran:', 'qué', 'buena', 'idea', 'llamar', 'al', 'fbi.', 'total,', 'eeuu', 'abusa', 'de', 'países', 'a', 'los', 'que', 'da', 'ayuda', 'policial,', '¿cierto', 'colombia', 'y', 'méxico?', 'http://t…']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: -1 (versión 1) Ó -140.0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@smallyson', 'rebeca', 'me', 'ajuda', 'eu', 'to', 'com', 'falta', 'de', 'ar', 'e', 'não', 'sei', 'onde', 'tá', 'minha', 'bombinha', 'de', 'ar', 'http://t.co/ebzyt4gzth']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@onlyxibest:', '@lvbradshaw', '@monarch544', 'it', 'will', 'be', 'the', 'of', 'my', 'week', '#wino', '🍷']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 2 (versión 1) Ó 41.5 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ["that's", 'the', 'of', 'evening', 'shift.', 'when', 'you', 'work', 'that', 'day,', 'your', 'whole', 'day', 'revolves', 'around', 'it.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: -2 (versión 1) Ó -48.0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['time', 'going', 'too', 'fast.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['müzik', 'bitince', 'bilgisayarın', 'havalandırma', 'sesiyle', 'baş', 'başa', 'kalmak', 'kadar', 'boktan', 'bir', 'durum', 'yok', 'amk', 'metin', 'şentürk', 'twitterda', '@metinsenturk']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['agustina', 'bigote', 'te', 'quiero', 'mucho', 'mucho', 'waa.', 'valum', 'estuvo', 'acá', '√']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['sou', 'apaixonada', 'por', 'garotos', 'que', 'amam', 'animais', '😍']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['i̇nsan', 'bazen', 'kendi', 'şanslarını', 'kendi', 'yaratıyor.ben', 'öyle', 'yaptım,kimseler', 'yoktu', 'yanımda.', '--cihan', 'özdemir']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@tomimondolo8:', 'solo', 'entiende', 'mi', 'locura', 'quien', 'comparte', 'mi', 'pasión.', 'carc', '★★☆★★']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# ...
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['aula', 'só', '15:15', 'agora']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['meryem', 'ile', 'bir', 'dedikodu', 'yaptık', 'varya', 'anlatamam', ':dd', 'metin', 'şentürk', 'twitterda', '@metinsenturk']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['nasıl', 'olurda???hâla', 'bıkmadığım', 'şarkı', 'tadındasın..']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['hadi', 'artık', 'sen', 'konuş,', 'herkes', 'sussun..', 'metin', 'şentürk', 'twitterda', '@metinsenturk']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['i', "don't", 'know', 'what', 'to', 'get', '9/11', 'for', 'its', 'birthday', 'tomorrow']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@beyonceexplicit', 'hello', 'beyonce', '♥♥♥']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['seriously', 'need', 'some', 'new', 'boots']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['metin', 'şentürk', 'twitterda', '@metinsenturk', 'yoksa', 'sizde', 'sabahın', 'ilk', 'ışıklarını', 'görmeden', 'uyuyamayanlardan', 'mısınız', '?']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@bieberannual:', '2', 'mins']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['la', 'entrada', 'perfecta', 'está', 'entre', 'los', '2/3', 'y', '3/4', 'del', 'estadio,', 'ni', 'está', 'tan', 'vacío', 'ni', 'aperrado.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@sonjimmons:', 'justin', 'bieber', 'http://t.co/ymhw1kwrbf']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@m_k_s_8:', 'للمتواجدين', 'الان', '✨⭕➊', 'فرصــتك', 'الآن', '✨⭕➋', 'لزيادة', 'متابعينك', '✨⭕➌', 'ريتويت', '✨⭕➍', 'فولومي', '✨⭕➎', 'فولوباك', '✨⭕➏', 'اضافة', 'من', 'عمل', 'ريتويت', '1', '#الأهلى_…']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['birthday', 'to', 'robbie', ',', '@arsenalfantv', 'you', 'offer', 'insight', '&amp;', 'coverage', 'on', 'the', 'mighty', 'arsenal', 'you', 'continue', 'to', '&amp;']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 10 (versión 1) Ó 14.8 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@bakunyufujin', 'オメーの電話番号はそれか違うのかどーなのかって聞いてんだろーがyo!それに答えりゃいーんだよ！']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['when', 'she', 'says', 'the', 'gets', 'every', 'time,,,,,,,', 'i', 'have', 'choice', 'but', 'to', 'do', 'the', '"daddy', 'got', 'stroke', 'dance"', 'a', 'hahahaha']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: -3 (versión 1) Ó -39.666666666666664 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['günlük', 'rapor:', '47', 'kişi', 'profilimi', 'gezdi', 'via', '(http://t.co/6vjqqqikjm)']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['downstairs', 'neighbros:', '1:00', 'pm', 'on', 'a', 'wednesday', 'is', 'generally', 'upon', 'as', 'time', 'not', 'meant', 'for', 'turning', 'up.', 'but', 'try.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 6 (versión 1) Ó 20.333333333333332 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@yungthanatos:', '"whatchu', 'been', 'doing', 'bro"', 'https://t.co/alzxiglssr']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@tab3na1:', 'برمجيات', 'جديده', 'لدى', 'مؤسسة', 'تابعنا', 'للتصميم', 'والبرمجة', 'وخدمات', 'الويب']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['pose', 'de', 'viado,', 'sem', 'camisa,', 'sorrindo,', 'mordendo', 'o', 'lábio,', 'sem', 'calças,', 'strip,', 'modelo', 'da', 'ck,', 'álbum', 'novo', 'em', 'outubro', 'é', 'mt', 'emoção', 'pra', 'uma', 'pessoa']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['ただひとつの']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['odeio', 'qnd', 'esqueço', 'de', 'enviar', 'a', 'msg.', 'daí', 'fico', 'q', 'nem', 'idiota', 'achando', 'que', 'fui', 'ignorada!', '😒']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['lçklçl']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@miga_hisoka', 'كلان', 'كبير', 'زي', 'ميقا', 'أكيد', 'بيكون', 'له', 'حاقدين', 'وبتواجهه', 'عقبات', 'واصلوا', 'يامزز', '3&gt;']
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['just', 'hit', 'some', 'speed', 'bumps', 'but', "i'm", 'not', 'gonna', 'let', 'them', 'bring', 'me', 'down.', 'just', 'gonna', 'regroup.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['#jagnation', '#x', '238']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@gyak615:', '@pink', '다모아카지노✔', 'ｍｘ４４４４。ｃｏｍ', '✔마닐라카지노로얄카지노태양성카지노★강남카지노다모아카지노강원카지노★베스트카지노썬시티카지노카지노잘하는법★타짜카지노서울카지노부산카지노사설카지노카지노베이크라운카지노★카지노팰리스카지노후기카지…']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['【定期】霊夢！主人公補正とか許さん！だいたい何やってもいいと浮かれてるから異変起こされるんだよ！恨めしい！']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['why', 'does', 'maddie', 'need', 'a', 'bajillion', '5sos', 'songs.', 'i', 'am', 'literally', 'the', 'one', 'to', 'get', 'them.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 4 (versión 1) Ó 24.25 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@nashgrier:', 'birthday', '@tfionash', 'i', 'you', 'soooo', 'much!', 'you', 'for', 'everything,', 'you', 'have', 'idea', 'how', 'much', 'you', 'mean', 'to', 'me.', "it'…"]
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 9 (versión 1) Ó 15.555555555555555 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@eglobalinfo:', 'eglobal', '|', 'coming', 'soon', 'http://t.co/c6ngxqlvi1']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 1 (versión 1) Ó 71.0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['(デング熱で学外休めるかな…)']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@dantyre:', '#inbound14!', 'the', 'tuesday', 'night', 'parties', 'are', 'back!', 'http://t.co/selgggfpdx']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['มัน00.01ละ', 'อีควาย']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['jangan', 'berubah', 'hanya', 'karena', 'cinta.', 'jika', 'dia', 'tak', 'bisa', 'menerima', 'kekuranganmu,', 'dia', 'tak', 'pantas', 'dapat', 'yg', 'terbaik', 'darimu.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@futboolfichajes:', 'hay', 'fecha!!', 'real', 'madrid-barcelona', 'jugarán', 'el', '25', 'de', 'octubre', 'a', 'las', '18hs', 'españa', 'por', 'la', '9', 'jornada.', 'http://t.co/heer77gnzg']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@katyperry:', "don't", '@hernameisbanks', 'debut', 'record', 'goddess', 'came', 'out', 'today', '&amp;', 'it', 'is', 'magnificent!', 'https://t.co/ja42jyk9x7', '#dontfuckwitha…']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: -1 (versión 1) Ó -144.0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['http://t.co/tautzaheyz', 'yazn', 'arkdşlr', 'bnc']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ["i'm", 'sure', 'they', 'were', 'up!', 'keep', 'trying."@botsboygeuk:@isphlyhoney', ':)will', 'do!tried', 'them', 'a', 'little', 'after', 'i', 'called', 'u', 'but', 'i', 'guess', 'it', 'hella', 'early.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@tarunvijay:', 'popularly', 'known', 'as', '"mahakavi', 'bharathiyar",', 'he', 'wrote', 'on', 'of', 'the', 'tamil', 'language,', 'and', 'odes', 'to', 'fighters', 'tilak,', 'gan…']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 4 (versión 1) Ó 35.0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@9gag:', 'my', 'mood', 'depends', 'on', 'how', 'my', 'hair', 'looks.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 3 (versión 1) Ó 17.333333333333332 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['368']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@jeremiahtolbert', '@saladinahmed', 'maybe', 'it', 'shoots', 'jelly', 'beans']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@fishnote:', '&lt;자산가', '상위', '10중', '7은', '구상금', '한푼', '안', '내&gt;', '건강보험', '구상금', '미납자', '중', '고액자산가', '상위', '10명은', '38억~135억원대의', '부자~', '이들의', '구상금', '미징수율', '80%대로', '전체', '평균의', '2배', '매해', '120억원의', '재정누수', 'http://t…']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['http://t.co/lbtoxop5gn', '-', 'tα', 'ονόματα', 'στη', 'δηκεβο', 'και', 'στη', 'δευαβ', '::', 'σιάτιστα', 'http://t.co/roqobr7cuu', 'via', '@webnode']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@nksubs:', 'leeteuk:', 'yeaaa', '(gets', 'up)', 'kangin:', 'hyung,', 'sit', 'down.', 'really', 'heechul:', "don't", 'be', 'that', 'to', 'my', 'friend!']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 2 (versión 1) Ó 55.0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['【自動】おやすみるきーヾ(･ω･o)']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@gabriele_corno:', 'history', 'museum', '@', 'london', 'by', 'richard', 'beresford', 'harris', '#architecture', '#prospective', 'http://t.co/cwibisjqdr']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 1 (versión 1) Ó 129.0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['@_mjodcx', 'تمم']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['だめだ動けないなんてことだ']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@bestofcancer:', '#cancer', 'needs', 'sincerity.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@gazoushu:', 'なんだこのアプリｗ', '登録したらビッチから連絡きて', '連絡先交換してデートしてきたｗｗ', 'しかも可愛すぎるしエロいし', '俺でもモテるとかｗｗ', 'マジで一回dlしてみてくれｗｗ', '→http://t.co/lfhgdaedlr', 'http://t.co/5ax…']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@30vs09:', 'fa)', '슈가군', '브이！ㅎㅎ', 'http://t.co/bxrdcriwop']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['a', 'participar', 'del', 'concurso', 'fotográfico', 'vélez', '2014.', 'sin', 'límite', 'de', 'edad', 'ni', 'equipamiento.', 'habrá', 'dos', 'categorías:', 'menores', 'y', 'mayores.']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['just', 'waking', 'up', 'in', 'the', 'morning', 'gotta', 'g', 'o', 'd', '❤️❤️❤️❤️❤️🙏🙏']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 2 (versión 1) Ó 30.0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@thisisyourevent:', 'فلل', 'للبيع', 'مساحات', 'مختلفة', 'في', 'غرب', 'وشمال', 'الرياض', 'للمفاهمة', '0551168155', '#داعش', '#عاجل', '#مؤتمر_الردة_في_جدة', '#الإسلام', '#فيلم']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@temasparamujer:', '3', 'consejos', 'y', 'asesoramiento', 'para', 'las', 'rupturas', 'matrimoniales', 'http://t.co/gxzfboavk7']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@bleachmei:', 'bleach好きな人rtふぁぼお願いします♪', '#bleach', '#rtした人フォローする', 'http://t.co/opyqpkbmce']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@hojimin31814:', 'ไอจีแทยอนมีทุกอย่างจริงๆนะ', 'ยกเว้นเจสสิก้า......']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@al_shiratori:', '【中毒性注意】納豆にちょい足しすると捗る禁断の廃人飯レシピまとめ', 'http://t.co/avydduelou', '今年見た情報の中で一番ヤバいヤツだった']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['rt', '@shinparu0330:', 'ぱるる姫ウイルス拡散', '#ぱるる', '#paruru', 'https://t.co/k28xr2mdhg']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
# --------------------------------------------------
# LAS SIGUIENTES PALABRAS: ['ffc', "ip's", 'symbaloo', '-', "ozbirn's", 'google', 'mix', '#fcslearn', '#ffcsoar', '#alpartners', '@ffcsoar', 'http://t.co/ub2wkowat8']
#
# TIENEN UN SENTIMIENTO ASOCIADO DE: 0 (versión 1) Ó 0 (versión 2)
